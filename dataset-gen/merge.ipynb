# %%
#!/usr/bin/env python3
"""
Dataset Merger Using Exact Same Approach as Working Code
========================================================

This script uses the EXACT same PDB processing approach as your working
binding site extraction code, but creates negative examples instead.

Requirements: pip install biopython pandas numpy

Usage:
    python exact_same_approach_merger.py

    Up until now, negative.csv contains the following categories: 
    Fabs (Antibodies): will only bind proteins, no small-molecule ligands
    Structural Proteins: 
        Elastin
        Fibrin
        Keratin
    Nucleases: will only bind DNA, no small molecule ligands 

    

"""

import pandas as pd
import numpy as np
import os
import time
import warnings
import json
import threading
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import logging

warnings.filterwarnings('ignore')

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Check and import BioPython (EXACT SAME as working code)
try:
    from Bio.PDB import PDBParser, PDBList
    from Bio.PDB.NeighborSearch import NeighborSearch
    from Bio.SeqUtils import seq1
    BIOPYTHON_AVAILABLE = True
    print("✓ BioPython available")
except ImportError:
    print("✗ BioPython not found. Install with: pip install biopython")
    BIOPYTHON_AVAILABLE = False

class NegativeExampleExtractor:
    """
    Extract negative examples using EXACT same approach as working code
    """
    
    def __init__(self, output_dir="negative_pdb_structures", max_workers=4):
        self.output_dir = output_dir
        self.max_workers = max_workers
        
        os.makedirs(output_dir, exist_ok=True)
        
        # Thread-safe storage
        self.negative_examples = []
        self.failed_pdbs = []
        self.lock = threading.Lock()
        
        # Initialize shared parser and downloader (EXACT SAME as working code)
        if BIOPYTHON_AVAILABLE:
            self.parser = PDBParser(QUIET=True)
            self.pdb_list = PDBList()
        
        print(f"Initialized negative extractor with {max_workers} threads")
    
    def clean_pdb_ids(self, pdb_list):
        """Extract valid PDB IDs from strings (EXACT SAME as working code)"""
        clean_ids = []
        
        for pdb_string in pdb_list:
            if isinstance(pdb_string, str):
                # Split by various separators
                for separator in [',', ';', '|', ' ']:
                    if separator in pdb_string:
                        pdb_string = pdb_string.replace(separator, ' ')
                
                # Extract individual PDB IDs
                for pdb_id in pdb_string.split():
                    pdb_id = pdb_id.strip().upper()
                    if len(pdb_id) == 4 and pdb_id.isalnum():
                        clean_ids.append(pdb_id)
        
        return list(set(clean_ids))
    
    def download_pdb_structure(self, pdb_id):
        """Download PDB structure (EXACT SAME as working code)"""
        expected_filename = os.path.join(self.output_dir, f"pdb{pdb_id.lower()}.ent")
        
        if os.path.exists(expected_filename):
            return expected_filename
        
        try:
            filename = self.pdb_list.retrieve_pdb_file(
                pdb_id, pdir=self.output_dir, file_format='pdb'
            )
            return filename if filename and os.path.exists(filename) else None
        except Exception:
            return None
    
    def extract_full_sequences(self, structure):
        """Extract complete protein sequences from PDB structure (EXACT SAME as working code)"""
        sequences = {}
        
        for model in structure:
            for chain in model:
                chain_id = chain.id
                sequence = ""
                
                # Get all protein residues in order
                protein_residues = [res for res in chain if res.id[0] == ' ']
                protein_residues.sort(key=lambda x: x.id[1])
                
                for residue in protein_residues:
                    try:
                        aa = seq1(residue.resname)
                        sequence += aa
                    except KeyError:
                        sequence += 'X'  # Unknown amino acid
                
                if sequence:
                    sequences[chain_id] = {
                        'sequence': sequence,
                        'length': len(sequence),
                        'residue_numbers': [res.id[1] for res in protein_residues]
                    }
        
        return sequences
    
    def create_negative_binding_info(self, chain_sequences):
        """Create negative binding info with all zeros (modified from working code)"""
        binding_info = {}
        
        for chain_id, seq_info in chain_sequences.items():
            # Create all-zero binding array (negative example)
            binding_array = np.zeros(seq_info['length'], dtype=int)
            
            binding_info[chain_id] = {
                'sequence': seq_info['sequence'],
                'binding_array': binding_array.tolist(),
                'binding_positions': [],  # Empty for negative examples
                'binding_residue_numbers': [],  # Empty for negative examples
                'num_binding_residues': 0  # Zero for negative examples
            }
        
        return binding_info
    
    def extract_negative_example_info(self, pdb_id, chain_sequences):
        """Extract negative example information (modified from working code)"""
        
        return {
            'pdb_id': pdb_id,
            'ligand_name': 'NONE',  # No ligand for negative examples
            'ligand_chain': '',
            'ligand_number': '',
            'num_contact_residues': 0,
            'contact_residues': [],  # Empty for negative examples
            'contact_sequence': '',
            'ligand_center': {'x': 0, 'y': 0, 'z': 0},  # No ligand center
            'binding_site_volume': 0.0,
            'chain_sequences': self.create_negative_binding_info(chain_sequences)
        }
    
    def process_single_pdb(self, pdb_id):
        """Process a single PDB structure (EXACT SAME structure as working code)"""
        if not BIOPYTHON_AVAILABLE:
            return {'pdb_id': pdb_id, 'status': 'error', 'reason': 'BioPython not available'}
        
        try:
            # Download structure (EXACT SAME as working code)
            filename = self.download_pdb_structure(pdb_id)
            if not filename:
                return {'pdb_id': pdb_id, 'status': 'error', 'reason': 'Download failed'}
            
            # Parse structure (EXACT SAME as working code)
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                structure = self.parser.get_structure(pdb_id, filename)
            
            # Extract sequences (EXACT SAME as working code)
            chain_sequences = self.extract_full_sequences(structure)
            
            if not chain_sequences:
                return {'pdb_id': pdb_id, 'status': 'error', 'reason': 'No protein chains found'}
            
            # Create negative example (modified from working code)
            negative_example = self.extract_negative_example_info(pdb_id, chain_sequences)
            
            # Thread-safe storage (EXACT SAME as working code)
            with self.lock:
                self.negative_examples.append(negative_example)
            
            return {
                'pdb_id': pdb_id, 
                'status': 'success', 
                'negative_example': negative_example,
                'num_chains': len(chain_sequences)
            }
            
        except Exception as e:
            error_msg = "Duplicate residue numbering" if "defined twice" in str(e) else str(e)
            with self.lock:
                self.failed_pdbs.append({'pdb_id': pdb_id, 'status': 'error', 'reason': error_msg})
            return {'pdb_id': pdb_id, 'status': 'error', 'reason': error_msg}
    
    def process_threaded(self, pdb_ids, max_structures=None, verbose=True):
        """Process PDB IDs using threading (EXACT SAME as working code)"""
        clean_ids = self.clean_pdb_ids(pdb_ids)
        
        if max_structures:
            clean_ids = clean_ids[:max_structures]
        
        print(f"Processing {len(clean_ids)} unique PDB IDs with {self.max_workers} threads...")
        
        completed = 0
        with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
            future_to_pdb = {executor.submit(self.process_single_pdb, pdb_id): pdb_id 
                           for pdb_id in clean_ids}
            
            for future in as_completed(future_to_pdb):
                pdb_id = future_to_pdb[future]
                completed += 1
                
                try:
                    result = future.result(timeout=300)
                    if verbose and completed % 10 == 0:
                        print(f"Completed {completed}/{len(clean_ids)} structures... "
                              f"Found {len(self.negative_examples)} negative examples so far")
                    
                    if result['status'] != 'success' and verbose and 'Download failed' not in result['reason']:
                        print(f"Failed {pdb_id}: {result['reason']}")
                
                except Exception as e:
                    with self.lock:
                        self.failed_pdbs.append({'pdb_id': pdb_id, 'status': 'error', 'reason': str(e)})
                    if verbose:
                        print(f"Exception processing {pdb_id}: {str(e)}")
        
        print(f"\nCompleted! Found {len(self.negative_examples)} negative examples")
        print(f"Successfully processed: {len(clean_ids) - len(self.failed_pdbs)}/{len(clean_ids)} structures")
        print(f"Failed: {len(self.failed_pdbs)} structures")
        
        return self.negative_examples, self.failed_pdbs
    
    def export_negative_results(self, output_file="negative_examples.csv"):
        """Export results with full sequence information (EXACT SAME format as working code)"""
        if not self.negative_examples:
            print("No negative examples to export")
            return None
        
        print(f"Exporting {len(self.negative_examples)} negative examples...")
        
        flattened_data = []
        for example in self.negative_examples:
            # Base information (EXACT SAME structure as working code)
            base_row = {
                'pdb_id': example['pdb_id'],
                'ligand_name': example['ligand_name'],
                'ligand_chain': example['ligand_chain'],
                'ligand_number': example['ligand_number'],
                'num_contact_residues': example['num_contact_residues'],
                'contact_sequence': example['contact_sequence'],
                'ligand_center_x': example['ligand_center']['x'],
                'ligand_center_y': example['ligand_center']['y'],
                'ligand_center_z': example['ligand_center']['z'],
                'binding_site_volume': example['binding_site_volume']
            }
            
            # Contact residue details (empty for negative examples)
            base_row.update({
                'contact_residues_list': '',
                'contact_residue_numbers': '',
                'contact_distances': ''
            })
            
            # Full sequence information for each chain (EXACT SAME as working code)
            for chain_id, chain_info in example['chain_sequences'].items():
                base_row.update({
                    f'chain_{chain_id}_sequence': chain_info['sequence'],
                    f'chain_{chain_id}_length': len(chain_info['sequence']),
                    f'chain_{chain_id}_binding_array': json.dumps(chain_info['binding_array']),
                    f'chain_{chain_id}_binding_positions': json.dumps(chain_info['binding_positions']),
                    f'chain_{chain_id}_binding_residue_numbers': json.dumps(chain_info['binding_residue_numbers']),
                    f'chain_{chain_id}_num_binding_residues': chain_info['num_binding_residues']
                })
            
            flattened_data.append(base_row)
        
        # Export to CSV (EXACT SAME as working code)
        df = pd.DataFrame(flattened_data)
        df.to_csv(output_file, index=False)
        
        print(f"✓ Exported to {output_file}")
        return df

def load_negative_pdb_ids(negative_csv_path):
    """Load PDB IDs from negative.csv file"""
    try:
        with open(negative_csv_path, 'r') as f:
            content = f.read().strip()
            pdb_ids = [pdb_id.strip() for pdb_id in content.split(',')]
            return [pdb_id for pdb_id in pdb_ids if pdb_id]
    except Exception as e:
        logger.error(f"Error loading negative PDB IDs: {str(e)}")
        return []

def merge_with_positive_dataset(negative_df, positive_csv_path, output_path):
    """Merge negative examples with positive dataset"""
    logger.info("Loading positive dataset...")
    positive_df = pd.read_csv(positive_csv_path, low_memory=False)
    logger.info(f"Loaded {len(positive_df)} positive examples")
    
    # Add binding labels
    positive_df['is_binding'] = 1
    negative_df['is_binding'] = 0
    
    # Ensure consistent columns
    all_columns = set(positive_df.columns) | set(negative_df.columns)
    
    for col in all_columns:
        if col not in positive_df.columns:
            positive_df[col] = ''
        if col not in negative_df.columns:
            negative_df[col] = ''
    
    # Match column order
    column_order = list(positive_df.columns)
    negative_df = negative_df[column_order]
    
    # Combine and shuffle
    merged_df = pd.concat([positive_df, negative_df], ignore_index=True)
    merged_df = merged_df.sample(frac=1, random_state=42).reset_index(drop=True)
    
    # Save result
    merged_df.to_csv(output_path, index=False)
    
    # Print summary
    positive_final = len(merged_df[merged_df['is_binding'] == 1])
    negative_final = len(merged_df[merged_df['is_binding'] == 0])
    
    logger.info("Merge complete!")
    logger.info(f"Final dataset: {len(merged_df)} total examples")
    logger.info(f"  - Positive (binding): {positive_final}")
    logger.info(f"  - Negative (non-binding): {negative_final}")
    logger.info(f"  - Balance ratio: {negative_final/positive_final:.2f}")

def main():
    """Main execution function using EXACT same approach as working code"""
    
    if not BIOPYTHON_AVAILABLE:
        print("ERROR: BioPython is required. Install with: pip install biopython")
        return
    
    # Configuration
    NEGATIVE_CSV = "negative.csv"
    POSITIVE_CSV = "binding_sites_with_sequences_30000.csv"
    OUTPUT_CSV = "merged_protein_dataset.csv"
    MAX_STRUCTURES = 30000  # Start with 5000 for testing
    MAX_WORKERS = 10
    
    print("="*60)
    print("DATASET MERGER USING EXACT SAME APPROACH")
    print("="*60)
    print(f"Negative CSV: {NEGATIVE_CSV}")
    print(f"Positive CSV: {POSITIVE_CSV}")
    print(f"Output CSV: {OUTPUT_CSV}")
    print(f"Max structures: {MAX_STRUCTURES}")
    print(f"Threads: {MAX_WORKERS}")
    
    # Step 1: Load negative PDB IDs
    logger.info("Loading negative PDB IDs...")
    negative_pdb_ids = load_negative_pdb_ids(NEGATIVE_CSV)
    logger.info(f"Found {len(negative_pdb_ids)} negative PDB IDs")
    
    if not negative_pdb_ids:
        print("ERROR: No negative PDB IDs found!")
        return
    
    # Step 2: Extract negative examples using EXACT same approach
    extractor = NegativeExampleExtractor(max_workers=MAX_WORKERS)
    negative_examples, failed_pdbs = extractor.process_threaded(
        negative_pdb_ids, max_structures=MAX_STRUCTURES
    )
    
    # Step 3: Export negative examples
    negative_df = extractor.export_negative_results("negative_examples_temp.csv")
    
    if negative_df is None or len(negative_df) == 0:
        print("ERROR: No negative examples were successfully processed!")
        return
    
    # Step 4: Merge with positive dataset
    logger.info("Merging with positive dataset...")
    merge_with_positive_dataset(negative_df, POSITIVE_CSV, OUTPUT_CSV)
    
    print(f"\n" + "="*60)
    print(f"SUCCESS! Merged dataset saved to: {OUTPUT_CSV}")
    print(f"Processed {len(negative_examples)} negative examples")
    print(f"Failed: {len(failed_pdbs)} structures")
    print("="*60)

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Loading negative PDB IDs...
# INFO:__main__:Found 14180 negative PDB IDs
# ✓ BioPython available
# ============================================================
# DATASET MERGER USING EXACT SAME APPROACH
# ============================================================
# Negative CSV: negative.csv
# Positive CSV: binding_sites_with_sequences_30000.csv
# Output CSV: merged_protein_dataset.csv
# Max structures: 5000
# Threads: 4
# Initialized negative extractor with 4 threads
# Processing 5000 unique PDB IDs with 4 threads...
# Downloading PDB structure '6vy5'...
# Downloading PDB structure '6qbt'...
# Downloading PDB structure '6n2x'...
# Downloading PDB structure '1kzk'...
# Downloading PDB structure '9hjo'...
# Downloading PDB structure '3h5b'...
# Downloading PDB structure '4gw4'...
# Downloading PDB structure '4z0v'...
# Downloading PDB structure '8k62'...
# Downloading PDB structure '7wcq'...
# Downloading PDB structure '8twa'...
# Downloading PDB structure '7g3t'...
# Downloading PDB structure '7g4x'...
# Completed 10/5000 structures... Found 10 negative examples so far
# Downloading PDB structure '4n96'...
# Desired structure doesn't exist
# Downloading PDB structure '8ez8'...
# Downloading PDB structure '7r8o'...
# Downloading PDB structure '1yyw'...
# Downloading PDB structure '1m5x'...
# Failed 7G3T: Duplicate residue numbering
# Downloading PDB structure '6x87'...
# Downloading PDB structure '1mfb'...
# Downloading PDB structure '3nfc'...
# Downloading PDB structure '6vo0'...
# Downloading PDB structure '8qpc'...
# Completed 20/5000 structures... Found 18 negative examples so farDownloading PDB structure '7bh8'...
#
# Downloading PDB structure '2xu1'...
# Desired structure doesn't exist
# Downloading PDB structure '5q3d'...
# Downloading PDB structure '6gfx'...
# Downloading PDB structure '7yos'...
# Downloading PDB structure '6b09'...
# Downloading PDB structure '5qoj'...
# Downloading PDB structure '3mnw'...
# Downloading PDB structure '3sq3'...
# Failed 7YOS: Duplicate residue numbering
# Downloading PDB structure '1jl2'...
# Downloading PDB structure '8g60'...
# Completed 30/5000 structures... Found 26 negative examples so far
# Downloading PDB structure '4ngb'...
# Desired structure doesn't exist
# Downloading PDB structure '9gmw'...
# Failed 3SQ3: Duplicate residue numbering
# Downloading PDB structure '1igj'...
# Downloading PDB structure '8g5o'...
# Downloading PDB structure '2d2d'...
# Downloading PDB structure '2yq2'...
# Downloading PDB structure '7onu'...
# Downloading PDB structure '7ota'...
# Downloading PDB structure '6m20'...
# Completed 40/5000 structures... Found 34 negative examples so far
# Downloading PDB structure '3ndw'...
# Downloading PDB structure '9cju'...
# Downloading PDB structure '5yet'...
# Downloading PDB structure '2zqb'...
# Downloading PDB structure '6s8b'...
# Downloading PDB structure '1a4k'...
# Downloading PDB structure '8dkl'...
# Downloading PDB structure '7ajt'...
# Downloading PDB structure '7s71'...
# Desired structure doesn't exist
# Downloading PDB structure '9cjp'...
# Completed 50/5000 structures... Found 43 negative examples so far
# Downloading PDB structure '7ein'...
# Downloading PDB structure '3hc3'...
# Downloading PDB structure '6ec0'...
# Downloading PDB structure '9f6i'...
# Downloading PDB structure '6ye3'...
# Failed 7EIN: Duplicate residue numbering
# Downloading PDB structure '2o9t'...
# Downloading PDB structure '6w3k'...
# Downloading PDB structure '2aeq'...
# Downloading PDB structure '2amd'...
# Downloading PDB structure '8zl9'...
# Completed 60/5000 structures... Found 52 negative examples so far
# Downloading PDB structure '5ckb'...
# Downloading PDB structure '7ar5'...
# Downloading PDB structure '7otx'...
# Downloading PDB structure '1gyg'...
# Downloading PDB structure '3g4t'...
# Downloading PDB structure '8e27'...
# Downloading PDB structure '6be4'...
# Downloading PDB structure '9dq5'...
# Downloading PDB structure '3ggv'...
# Downloading PDB structure '1kwf'...
# Completed 70/5000 structures... Found 62 negative examples so farDownloading PDB structure '9dwh'...
#
# Downloading PDB structure '5q4q'...
# Downloading PDB structure '7m7w'...
# Downloading PDB structure '7gc8'...
# Downloading PDB structure '4dw2'...
# Downloading PDB structure '1aid'...
# Downloading PDB structure '5f6j'...
# Downloading PDB structure '3jbx'...
# Failed 4DW2: Duplicate residue numbering
# Downloading PDB structure '4ndi'...
# Downloading PDB structure '9mn4'...
# Completed 80/5000 structures... Found 71 negative examples so far
# Downloading PDB structure '4rec'...
# Downloading PDB structure '8ppl'...
# Downloading PDB structure '2ypl'...
# Downloading PDB structure '6d9j'...
# Desired structure doesn't exist
# Downloading PDB structure '7tpd'...
# Downloading PDB structure '4jdt'...
# Desired structure doesn't exist
# Downloading PDB structure '1e4w'...
# Downloading PDB structure '4zwe'...
# Downloading PDB structure '6u8c'...
# Downloading PDB structure '8yop'...
# Downloading PDB structure '3t1i'...
# Completed 90/5000 structures... Found 79 negative examples so far
# Downloading PDB structure '1flr'...
# Downloading PDB structure '7zoo'...
# Desired structure doesn't exist
# Downloading PDB structure '1bz7'...
# Downloading PDB structure '5reo'...
# Downloading PDB structure '6djf'...
# Downloading PDB structure '7gmc'...
# Downloading PDB structure '7uxa'...
# Downloading PDB structure '7sh7'...
# Downloading PDB structure '7bqy'...
# Completed 100/5000 structures... Found 88 negative examples so far
# Downloading PDB structure '7xhg'...
# Downloading PDB structure '5wz4'...
# Downloading PDB structure '3uwj'...
# Downloading PDB structure '7gi3'...
# Downloading PDB structure '7m9v'...
# Downloading PDB structure '3e42'...
# Downloading PDB structure '7n3d'...
# Downloading PDB structure '2kb5'...
# Failed 7GI3: Duplicate residue numbering
# Downloading PDB structure '5q7m'...
# Downloading PDB structure '2v88'...
# Completed 110/5000 structures... Found 97 negative examples so far
# Downloading PDB structure '4m9h'...
# Downloading PDB structure '4p9h'...
# Downloading PDB structure '2vbl'...
# Downloading PDB structure '4cig'...
# Downloading PDB structure '3eys'...
# Downloading PDB structure '2pfz'...
# Downloading PDB structure '6al4'...
# Failed 2VBL: Duplicate residue numbering
# Downloading PDB structure '5vph'...
# Downloading PDB structure '2f5t'...
# Downloading PDB structure '4k3k'...
# Downloading PDB structure '7z3p'...
# Completed 120/5000 structures... Found 106 negative examples so far
# Downloading PDB structure '1ang'...
# Downloading PDB structure '8v5t'...
# Downloading PDB structure '4nrv'...
# Downloading PDB structure '2qi3'...
# Downloading PDB structure '7ghj'...
# Downloading PDB structure '7syw'...
# Downloading PDB structure '1bv9'...
# Downloading PDB structure '8drz'...
# Downloading PDB structure '1de8'...
# Completed 130/5000 structures... Found 116 negative examples so far
# Downloading PDB structure '4msw'...
# Downloading PDB structure '8vc7'...
# Downloading PDB structure '1zsf'...
# Downloading PDB structure '6ctk'...
# Downloading PDB structure '7dr9'...
# Downloading PDB structure '8z95'...
# Downloading PDB structure '2f56'...
# Downloading PDB structure '3utz'...
# Downloading PDB structure '7sbv'...
# Downloading PDB structure '7glj'...
# Completed 140/5000 structures... Found 126 negative examples so far
# Downloading PDB structure '1cf8'...
# Downloading PDB structure '3v4y'...
# Downloading PDB structure '7ggv'...
# Downloading PDB structure '8dtk'...
# Downloading PDB structure '8huu'...
# Downloading PDB structure '7icq'...
# Downloading PDB structure '6mjz'...
# Downloading PDB structure '1ni0'...
# Downloading PDB structure '3mlz'...
# Downloading PDB structure '1fid'...
# Completed 150/5000 structures... Found 136 negative examples so far
# Downloading PDB structure '6s58'...
# Downloading PDB structure '1asu'...
# Downloading PDB structure '7mat'...
# Downloading PDB structure '5rl0'...
# Downloading PDB structure '9ik2'...
# Downloading PDB structure '6k1b'...
# Downloading PDB structure '8p87'...
# Desired structure doesn't exist
# Downloading PDB structure '8uzz'...
# Downloading PDB structure '6wh9'...
# Downloading PDB structure '3zsy'...
# Completed 160/5000 structures... Found 145 negative examples so farDownloading PDB structure '1h2l'...
#
# Downloading PDB structure '3nr6'...
# Downloading PDB structure '7lyi'...
# Downloading PDB structure '7l20'...
# Downloading PDB structure '6w7k'...
# Downloading PDB structure '8vn0'...
# Downloading PDB structure '7rvp'...
# Desired structure doesn't exist
# Downloading PDB structure '1mju'...
# Downloading PDB structure '7v05'...
# Downloading PDB structure '7m6g'...
# Completed 170/5000 structures... Found 154 negative examples so far
# Downloading PDB structure '7lea'...
# Downloading PDB structure '1hkl'...
# Downloading PDB structure '6zce'...
# Downloading PDB structure '8vvo'...
# Downloading PDB structure '1g9n'...
# Downloading PDB structure '3of9'...
# Downloading PDB structure '6wx1'...
# Downloading PDB structure '5q4a'...
# Downloading PDB structure '6mtq'...
# Downloading PDB structure '5oi8'...
# Completed 180/5000 structures... Found 164 negative examples so farDownloading PDB structure '6mr8'...
#
# Downloading PDB structure '2wiz'...
# Downloading PDB structure '4zkf'...
# Downloading PDB structure '8w83'...
# Downloading PDB structure '2ivy'...
# Downloading PDB structure '8dzc'...
# Downloading PDB structure '3knt'...
# Downloading PDB structure '8yb7'...
# Downloading PDB structure '2rhb'...
# Downloading PDB structure '1wv7'...
# Downloading PDB structure '7wly'...
# Completed 190/5000 structures... Found 174 negative examples so far
# Downloading PDB structure '9b6n'...
# Downloading PDB structure '9jij'...
# Downloading PDB structure '4ajy'...
# Downloading PDB structure '1dlf'...
# Downloading PDB structure '4h8w'...
# Downloading PDB structure '9npx'...
# Downloading PDB structure '7m51'...
# Downloading PDB structure '8hvv'...
# Downloading PDB structure '4ph0'...
# Completed 200/5000 structures... Found 184 negative examples so farDownloading PDB structure '1hii'...
#
# Downloading PDB structure '4d0k'...
# Downloading PDB structure '3d9a'...
# Downloading PDB structure '1bln'...
# Downloading PDB structure '1e55'...
# Downloading PDB structure '7t46'...
# Downloading PDB structure '6vqx'...
# Downloading PDB structure '8rh2'...
# Downloading PDB structure '5xot'...
# Downloading PDB structure '7ufo'...
# Completed 210/5000 structures... Found 194 negative examples so far
# Downloading PDB structure '1sgu'...
# Downloading PDB structure '5e5k'...
# Downloading PDB structure '8u5b'...
# Downloading PDB structure '6npm'...
# Downloading PDB structure '8x9a'...
# Downloading PDB structure '5ye4'...
# Downloading PDB structure '3csy'...
# Downloading PDB structure '3oko'...
# Downloading PDB structure '5q4s'...
# Downloading PDB structure '4kwu'...
# Downloading PDB structure '9gms'...
# Completed 220/5000 structures... Found 204 negative examples so far
# Downloading PDB structure '5w9g'...
# Desired structure doesn't exist
# Downloading PDB structure '6h0m'...
# Downloading PDB structure '4zg7'...
# Downloading PDB structure '7gfo'...
# Downloading PDB structure '7l02'...
# Downloading PDB structure '2vld'...
# Downloading PDB structure '8tp7'...
# Downloading PDB structure '1mj7'...
# Downloading PDB structure '7bua'...
# Completed 230/5000 structures... Found 213 negative examples so far
# Downloading PDB structure '2p66'...
# Downloading PDB structure '4q1y'...
# Downloading PDB structure '7ptu'...
# Downloading PDB structure '7cun'...
# Downloading PDB structure '4v8x'...
# Downloading PDB structure '7gdq'...
# Downloading PDB structure '7ufz'...
# Desired structure doesn't exist
# Downloading PDB structure '2qkb'...
# Downloading PDB structure '5ush'...
# Completed 240/5000 structures... Found 221 negative examples so far
# Failed 7GDQ: Duplicate residue numbering
# Downloading PDB structure '4org'...
# Downloading PDB structure '2kqd'...
# Downloading PDB structure '1k6c'...
# Downloading PDB structure '2ien'...
# Downloading PDB structure '6e65'...
# Downloading PDB structure '1suz'...
# Downloading PDB structure '5mx3'...
# Downloading PDB structure '8qsj'...
# Downloading PDB structure '2o4x'...
# Downloading PDB structure '4osu'...
# Downloading PDB structure '7gin'...
# Completed 250/5000 structures... Found 231 negative examples so far
# Downloading PDB structure '6s0m'...
# Desired structure doesn't exist
# Downloading PDB structure '8vn5'...
# Downloading PDB structure '6zqb'...
# Downloading PDB structure '4ueh'...
# Downloading PDB structure '7zf6'...
# Downloading PDB structure '5db9'...
# Downloading PDB structure '3wkm'...
# Downloading PDB structure '3v5k'...
# Desired structure doesn't exist
# Downloading PDB structure '8d21'...
# Downloading PDB structure '7tgr'...
# Completed 260/5000 structures... Found 239 negative examples so farDownloading PDB structure '4f0q'...
#
# Downloading PDB structure '3mvh'...
# Downloading PDB structure '1pn3'...
# Downloading PDB structure '1mlc'...
# Downloading PDB structure '7ogk'...
# Downloading PDB structure '2n7k'...
# Downloading PDB structure '8tqp'...
# Downloading PDB structure '3o9h'...
# Downloading PDB structure '8ca8'...
# Downloading PDB structure '6crb'...
# Completed 270/5000 structures... Found 249 negative examples so far
# Downloading PDB structure '7xry'...
# Downloading PDB structure '7x93'...
# Downloading PDB structure '7gb8'...
# Desired structure doesn't exist
# Downloading PDB structure '2ak1'...
# Downloading PDB structure '4xhj'...
# Downloading PDB structure '9gku'...
# Downloading PDB structure '5qhi'...
# Downloading PDB structure '8t7s'...
# Downloading PDB structure '7t9h'...
# Downloading PDB structure '7jp0'...
# Desired structure doesn't exist
# Completed 280/5000 structures... Found 257 negative examples so far
# Downloading PDB structure '6ezx'...
# Downloading PDB structure '7elw'...
# Downloading PDB structure '9b0p'...
# Downloading PDB structure '1zp8'...
# Downloading PDB structure '4u6g'...
# Downloading PDB structure '8usy'...
# Desired structure doesn't exist
# Downloading PDB structure '7t41'...
# Downloading PDB structure '7td8'...
# Downloading PDB structure '6ug9'...
# Downloading PDB structure '6bla'...
# Completed 290/5000 structures... Found 266 negative examples so far
# Downloading PDB structure '7gbw'...
# Downloading PDB structure '1gef'...
# Downloading PDB structure '4ahn'...
# Failed 6UG9: No protein chains found
# Downloading PDB structure '5bs4'...
# Downloading PDB structure '1cqg'...
# Downloading PDB structure '8c3b'...
# Downloading PDB structure '8djj'...
# Downloading PDB structure '2c1l'...
# Downloading PDB structure '7mf1'...
# Desired structure doesn't exist
# Downloading PDB structure '9b2m'...
# Completed 300/5000 structures... Found 274 negative examples so far
# Downloading PDB structure '7i1c'...
# Downloading PDB structure '6nex'...
# Downloading PDB structure '1qyy'...
# Downloading PDB structure '6wc1'...
# Downloading PDB structure '5gzr'...
# Downloading PDB structure '8uhh'...
# Downloading PDB structure '2bex'...
# Downloading PDB structure '4ywk'...
# Downloading PDB structure '6fg2'...
# Downloading PDB structure '8ptk'...
# Completed 310/5000 structures... Found 284 negative examples so far
# Downloading PDB structure '6kx1'...
# Downloading PDB structure '3ec3'...
# Downloading PDB structure '2y7l'...
# Desired structure doesn't exist
# Downloading PDB structure '4o9m'...
# Downloading PDB structure '9c7f'...
# Downloading PDB structure '9ica'...
# Downloading PDB structure '2vit'...
# Downloading PDB structure '4pra'...
# Downloading PDB structure '5ola'...
# Downloading PDB structure '7b77'...
# Downloading PDB structure '5cjx'...
# Completed 320/5000 structures... Found 293 negative examples so far
# Downloading PDB structure '6c9u'...
# Downloading PDB structure '5mlo'...
# Downloading PDB structure '8hhu'...
# Downloading PDB structure '7r6w'...
# Downloading PDB structure '9kef'...
# Downloading PDB structure '6u6b'...
# Downloading PDB structure '7m9g'...
# Downloading PDB structure '2z91'...
# Downloading PDB structure '6z3k'...
# Completed 330/5000 structures... Found 303 negative examples so far
# Downloading PDB structure '4cf9'...
# Downloading PDB structure '6tnz'...
# Downloading PDB structure '6dw5'...
# Downloading PDB structure '3ebn'...
# Downloading PDB structure '8ds7'...
# Downloading PDB structure '7gns'...
# Downloading PDB structure '7m9p'...
# Downloading PDB structure '6vvu'...
# Downloading PDB structure '2qi0'...
# Downloading PDB structure '9au2'...
# Downloading PDB structure '5u4r'...
# Completed 340/5000 structures... Found 313 negative examples so far
# Downloading PDB structure '1mtb'...
# Downloading PDB structure '2lje'...
# Downloading PDB structure '5m7m'...
# Downloading PDB structure '3f7v'...
# Downloading PDB structure '7k75'...
# Downloading PDB structure '5rei'...
# Downloading PDB structure '5smn'...
# Downloading PDB structure '2r5p'...
# Downloading PDB structure '1ex0'...
# Completed 350/5000 structures... Found 323 negative examples so farDownloading PDB structure '5vkd'...
#
# Downloading PDB structure '6b40'...
# Downloading PDB structure '4bz2'...
# Downloading PDB structure '6ss0'...
# Downloading PDB structure '6naj'...
# Downloading PDB structure '8zc4'...
# Desired structure doesn't exist
# Downloading PDB structure '7jsi'...
# Downloading PDB structure '7ge0'...
# Downloading PDB structure '6q1k'...
# Downloading PDB structure '2aod'...
# Completed 360/5000 structures... Found 332 negative examples so far
# Downloading PDB structure '5rf7'...
# Downloading PDB structure '5q3r'...
# Downloading PDB structure '8caj'...
# Downloading PDB structure '6bfq'...
# Downloading PDB structure '2ajy'...
# Downloading PDB structure '9bao'...
# Desired structure doesn't exist
# Downloading PDB structure '8qyh'...
# Downloading PDB structure '5v5m'...
# Downloading PDB structure '6f2y'...
# Downloading PDB structure '8ekf'...
# Completed 370/5000 structures... Found 341 negative examples so far
# Downloading PDB structure '4mdj'...
# Downloading PDB structure '7t45'...
# Downloading PDB structure '7m9z'...
# Desired structure doesn't exist
# Downloading PDB structure '8xel'...
# Downloading PDB structure '9rj8'...
# Downloading PDB structure '6vrd'...
# Desired structure doesn't exist
# Downloading PDB structure '1d4k'...
# Downloading PDB structure '6ctv'...
# Downloading PDB structure '7qbb'...
# Downloading PDB structure '3sn8'...
# Completed 380/5000 structures... Found 349 negative examples so far
# Downloading PDB structure '4kk5'...
# Downloading PDB structure '9bo5'...
# Downloading PDB structure '1rul'...
# Downloading PDB structure '8t7f'...
# Downloading PDB structure '7ru5'...
# Downloading PDB structure '5rfw'...
# Downloading PDB structure '5mu0'...
# Downloading PDB structure '5a77'...
# Downloading PDB structure '8s5a'...
# Downloading PDB structure '7f35'...
# Completed 390/5000 structures... Found 359 negative examples so far
# Downloading PDB structure '7q9j'...
# Downloading PDB structure '7g2p'...
# Downloading PDB structure '8v55'...
# Downloading PDB structure '6phg'...
# Downloading PDB structure '4nyt'...
# Downloading PDB structure '6n0d'...
# Downloading PDB structure '5yep'...
# Downloading PDB structure '8k2a'...
# Downloading PDB structure '7gdr'...
# Downloading PDB structure '6pzz'...
# Completed 400/5000 structures... Found 369 negative examples so farDownloading PDB structure '2puq'...
#
# Desired structure doesn't exist
# Downloading PDB structure '4id1'...
# Downloading PDB structure '3hqu'...
# Downloading PDB structure '3zcm'...
# Downloading PDB structure '6ea9'...
# Downloading PDB structure '6n19'...
# Downloading PDB structure '7mdj'...
# Downloading PDB structure '7daa'...
# Downloading PDB structure '1wjc'...
# Downloading PDB structure '9jif'...
# Completed 410/5000 structures... Found 378 negative examples so far
# Downloading PDB structure '8crb'...
# Downloading PDB structure '8d4m'...
# Downloading PDB structure '6avu'...
# Downloading PDB structure '6ehi'...
# Downloading PDB structure '6ie3'...
# Downloading PDB structure '8y0x'...
# Downloading PDB structure '3krn'...
# Downloading PDB structure '7lmd'...
# Desired structure doesn't exist
# Downloading PDB structure '8zov'...
# Downloading PDB structure '6shc'...
# Completed 420/5000 structures... Found 387 negative examples so far
# Downloading PDB structure '3r4b'...
# Downloading PDB structure '7ahx'...
# Failed 7LMD: Duplicate residue numbering
# Downloading PDB structure '7xrs'...
# Downloading PDB structure '4mjr'...
# Failed 3R4B: Duplicate residue numbering
# Downloading PDB structure '7rdj'...
# Downloading PDB structure '2vc2'...
# Downloading PDB structure '2gth'...
# Downloading PDB structure '6yhr'...
# Downloading PDB structure '8dfg'...
# Downloading PDB structure '7ouf'...
# Failed 7AHX: Duplicate residue numbering
# Downloading PDB structure '5rh8'...
# Completed 430/5000 structures... Found 394 negative examples so far
# Downloading PDB structure '8zhl'...
# Downloading PDB structure '4uok'...
# Desired structure doesn't exist
# Downloading PDB structure '7neq'...
# Downloading PDB structure '3b2u'...
# Downloading PDB structure '2e6n'...
# Downloading PDB structure '5dbc'...
# Downloading PDB structure '8umu'...
# Downloading PDB structure '7f2s'...
# Failed 3B2U: Duplicate residue numbering
# Downloading PDB structure '8kda'...
# Completed 440/5000 structures... Found 402 negative examples so far
# Downloading PDB structure '7mqf'...
# Downloading PDB structure '4oke'...
# Downloading PDB structure '6cse'...
# Downloading PDB structure '3ckt'...
# Downloading PDB structure '6oxa'...
# Downloading PDB structure '4ers'...
# Downloading PDB structure '7kph'...
# Desired structure doesn't exist
# Downloading PDB structure '6r6g'...
# Downloading PDB structure '7y0o'...
# Downloading PDB structure '6ctj'...
# Completed 450/5000 structures... Found 411 negative examples so far
# Downloading PDB structure '7glz'...
# Desired structure doesn't exist
# Downloading PDB structure '8y4h'...
# Downloading PDB structure '8sxx'...
# Downloading PDB structure '7ogl'...
# Downloading PDB structure '4fcj'...
# Downloading PDB structure '7x6o'...
# Downloading PDB structure '5ggs'...
# Downloading PDB structure '7dm2'...
# Downloading PDB structure '5ezo'...
# Downloading PDB structure '3l5w'...
# Downloading PDB structure '9cpt'...
# Completed 460/5000 structures... Found 420 negative examples so far
# Downloading PDB structure '7en8'...
# Downloading PDB structure '7g4t'...
# Downloading PDB structure '1qfu'...
# Downloading PDB structure '5mhp'...
# Downloading PDB structure '2zu5'...
# Downloading PDB structure '6zon'...
# Downloading PDB structure '8v06'...
# Downloading PDB structure '7ma8'...
# Downloading PDB structure '9hjh'...
# Completed 470/5000 structures... Found 430 negative examples so far
# Downloading PDB structure '4wyq'...
# Desired structure doesn't exist
# Downloading PDB structure '8oin'...
# Desired structure doesn't exist
# Downloading PDB structure '4doa'...
# Downloading PDB structure '7qh7'...
# Downloading PDB structure '7akj'...
# Desired structure doesn't exist
# Downloading PDB structure '7x95'...
# Downloading PDB structure '3ix3'...
# Downloading PDB structure '6v06'...
# Downloading PDB structure '6j9l'...
# Downloading PDB structure '2w2g'...
# Completed 480/5000 structures... Found 437 negative examples so farDownloading PDB structure '1duc'...
#
# Downloading PDB structure '2h43'...
# Failed 2W2G: Duplicate residue numbering
# Downloading PDB structure '7jsu'...
# Downloading PDB structure '2nqd'...
# Downloading PDB structure '5obf'...
# Downloading PDB structure '1hpo'...
# Downloading PDB structure '5q37'...
# Downloading PDB structure '9fqo'...
# Downloading PDB structure '7l14'...
# Downloading PDB structure '7lq7'...
# Completed 490/5000 structures... Found 446 negative examples so farDownloading PDB structure '3w9e'...
#
# Downloading PDB structure '8doz'...
# Failed 7LQ7: No protein chains found
# Downloading PDB structure '8fxu'...
# Downloading PDB structure '7nzm'...
# Downloading PDB structure '8urh'...
# Downloading PDB structure '9jcy'...
# Desired structure doesn't exist
# Downloading PDB structure '1ztz'...
# Downloading PDB structure '1xl2'...
# Downloading PDB structure '8vmx'...
# Downloading PDB structure '2hnd'...
# Completed 500/5000 structures... Found 454 negative examples so far
# Downloading PDB structure '8sef'...
# Downloading PDB structure '6ctw'...
# Downloading PDB structure '6y9a'...
# Downloading PDB structure '5dmi'...
# Downloading PDB structure '4xc1'...
# Downloading PDB structure '3eaj'...
# Downloading PDB structure '9mru'...
# Downloading PDB structure '5q46'...
# Downloading PDB structure '7vk2'...
# Downloading PDB structure '6vbw'...
# Downloading PDB structure '7g3c'...Completed 510/5000 structures... Found 464 negative examples so far
#
# Downloading PDB structure '1e6o'...
# Downloading PDB structure '4aei'...
# Downloading PDB structure '6ugs'...
# Downloading PDB structure '6vyq'...
# Downloading PDB structure '3zkx'...
# Downloading PDB structure '4tpy'...
# Downloading PDB structure '6w3a'...
# Desired structure doesn't exist
# Downloading PDB structure '7gb9'...
# Downloading PDB structure '5vic'...
# Downloading PDB structure '5wkm'...
# Completed 520/5000 structures... Found 473 negative examples so far
# Downloading PDB structure '5dk5'...
# Downloading PDB structure '3lik'...
# Downloading PDB structure '3d45'...
# Downloading PDB structure '9r4s'...
# Downloading PDB structure '1rzi'...
# Downloading PDB structure '6vh3'...
# Downloading PDB structure '6yax'...
# Downloading PDB structure '6t57'...
# Downloading PDB structure '9art'...
# Completed 530/5000 structures... Found 483 negative examples so farDownloading PDB structure '3dlr'...
#
# Desired structure doesn't exist
# Downloading PDB structure '3n2v'...
# Downloading PDB structure '6eb1'...
# Downloading PDB structure '4isj'...
# Downloading PDB structure '4kty'...
# Downloading PDB structure '6n7u'...
# Downloading PDB structure '7jw2'...
# Downloading PDB structure '2noi'...
# Downloading PDB structure '2qnf'...
# Downloading PDB structure '7dun'...
# Completed 540/5000 structures... Found 492 negative examples so farDownloading PDB structure '5reu'...
#
# Downloading PDB structure '3ui3'...
# Downloading PDB structure '7k07'...
# Downloading PDB structure '6qa2'...
# Downloading PDB structure '4mjp'...
# Downloading PDB structure '3pgf'...
# Downloading PDB structure '1mk7'...
# Downloading PDB structure '6e7j'...
# Downloading PDB structure '5nh0'...
# Downloading PDB structure '8kfr'...
# Completed 550/5000 structures... Found 502 negative examples so far
# Downloading PDB structure '2hpf'...
# Downloading PDB structure '7lmc'...
# Downloading PDB structure '1wdj'...
# Downloading PDB structure '5i1j'...
# Downloading PDB structure '8x0t'...
# Downloading PDB structure '7yck'...
# Downloading PDB structure '4l5f'...
# Downloading PDB structure '8zpp'...
# Downloading PDB structure '3jau'...
# Downloading PDB structure '1t9j'...
# Completed 560/5000 structures... Found 512 negative examples so far
# Downloading PDB structure '5tdp'...
# Downloading PDB structure '7jwg'...
# Downloading PDB structure '7rew'...
# Downloading PDB structure '6zec'...
# Downloading PDB structure '7tuh'...
# Downloading PDB structure '7l8b'...
# Downloading PDB structure '7g2u'...
# Downloading PDB structure '3u7y'...
# Downloading PDB structure '7bud'...
# Downloading PDB structure '7mq8'...
# Completed 570/5000 structures... Found 522 negative examples so far
# Downloading PDB structure '2vf7'...
# Desired structure doesn't exist
# Downloading PDB structure '2e52'...
# Downloading PDB structure '8ghr'...
# Downloading PDB structure '3grw'...
# Downloading PDB structure '4nha'...
# Downloading PDB structure '8ifr'...
# Downloading PDB structure '1vik'...
# Downloading PDB structure '2qql'...
# Downloading PDB structure '8e63'...
# Downloading PDB structure '2vxu'...
# Completed 580/5000 structures... Found 531 negative examples so far
# Downloading PDB structure '4jfy'...
# Downloading PDB structure '4lvn'...
# Downloading PDB structure '8fnj'...
# Downloading PDB structure '4cc9'...
# Downloading PDB structure '7uzd'...
# Downloading PDB structure '6hhi'...
# Downloading PDB structure '7gmg'...
# Downloading PDB structure '7x2k'...
# Downloading PDB structure '7aph'...
# Downloading PDB structure '4u4u'...
# Completed 590/5000 structures... Found 541 negative examples so farDownloading PDB structure '7k9j'...
#
# Desired structure doesn't exist
# Desired structure doesn't exist
# Downloading PDB structure '4m1g'...
# Downloading PDB structure '7o7f'...
# Downloading PDB structure '6njy'...
# Downloading PDB structure '8txt'...
# Downloading PDB structure '9cl7'...
# Downloading PDB structure '9bf0'...
# Downloading PDB structure '6xey'...
# Desired structure doesn't exist
# Downloading PDB structure '3ufn'...
# Downloading PDB structure '7k7i'...
# Completed 600/5000 structures... Found 548 negative examples so far
# Downloading PDB structure '6rs5'...
# Downloading PDB structure '6roe'...
# Downloading PDB structure '9cnu'...
# Downloading PDB structure '6h25'...
# Downloading PDB structure '7dhj'...
# Downloading PDB structure '4bow'...
# Downloading PDB structure '7ewi'...
# Failed 6ROE: No protein chains found
# Downloading PDB structure '1udo'...
# Downloading PDB structure '8p55'...
# Downloading PDB structure '1mmi'...
# Completed 610/5000 structures... Found 557 negative examples so far
# Downloading PDB structure '7ttm'...
# Downloading PDB structure '6fjw'...
# Downloading PDB structure '7gf1'...
# Downloading PDB structure '5h35'...
# Downloading PDB structure '8hol'...
# Downloading PDB structure '8tft'...
# Downloading PDB structure '9b3n'...
# Downloading PDB structure '9d5d'...
# Downloading PDB structure '4n98'...
# Downloading PDB structure '7vwo'...
# Completed 620/5000 structures... Found 567 negative examples so far
# Downloading PDB structure '5rgw'...
# Desired structure doesn't exist
# Downloading PDB structure '3u4e'...
# Downloading PDB structure '8ak5'...
# Downloading PDB structure '5mth'...
# Downloading PDB structure '7uap'...
# Downloading PDB structure '8fl3'...
# Downloading PDB structure '3kfs'...
# Desired structure doesn't exist
# Downloading PDB structure '9c69'...
# Downloading PDB structure '8t8i'...
# Downloading PDB structure '7vk6'...
# Completed 630/5000 structures... Found 575 negative examples so farDownloading PDB structure '3lj1'...
#
# Downloading PDB structure '7u8y'...
# Downloading PDB structure '7lzw'...
# Downloading PDB structure '6rly'...
# Downloading PDB structure '1u92'...
# Downloading PDB structure '4why'...
# Downloading PDB structure '5m9p'...
# Downloading PDB structure '5ht2'...
# Downloading PDB structure '6b5t'...
# Downloading PDB structure '7gs1'...
# Downloading PDB structure '1ed1'...
# Completed 640/5000 structures... Found 585 negative examples so far
# Downloading PDB structure '1rt7'...
# Downloading PDB structure '2xo6'...
# Downloading PDB structure '7xr9'...
# Downloading PDB structure '7wuh'...
# Downloading PDB structure '8prx'...
# Downloading PDB structure '9ggp'...
# Downloading PDB structure '8b7f'...
# Downloading PDB structure '8czw'...
# Downloading PDB structure '6dw2'...
# Completed 650/5000 structures... Found 595 negative examples so far
# Downloading PDB structure '7vag'...
# Downloading PDB structure '8y3l'...
# Downloading PDB structure '5ahr'...
# Downloading PDB structure '1ebz'...
# Downloading PDB structure '7p40'...
# Desired structure doesn't exist
# Downloading PDB structure '8r23'...
# Downloading PDB structure '5q3c'...
# Downloading PDB structure '6oej'...
# Downloading PDB structure '1d02'...
# Downloading PDB structure '9nnd'...
# Completed 660/5000 structures... Found 604 negative examples so farDownloading PDB structure '2je4'...
#
# Downloading PDB structure '7udg'...
# Downloading PDB structure '8c7j'...
# Failed 7P40: Duplicate residue numbering
# Downloading PDB structure '6jp7'...
# Downloading PDB structure '2i4u'...
# Downloading PDB structure '8okk'...
# Downloading PDB structure '7s0j'...
# Downloading PDB structure '3nh7'...
# Downloading PDB structure '8uiz'...
# Downloading PDB structure '2fvp'...
# Completed 670/5000 structures... Found 613 negative examples so far
# Downloading PDB structure '2fat'...
# Desired structure doesn't exist
# Downloading PDB structure '6q1g'...
# Downloading PDB structure '6a45'...
# Downloading PDB structure '1fk9'...
# Downloading PDB structure '1n3e'...
# Downloading PDB structure '7lia'...
# Downloading PDB structure '1bg3'...
# Failed 1N3E: No protein chains found
# Downloading PDB structure '5esa'...
# Downloading PDB structure '6zqg'...
# Downloading PDB structure '8urf'...
# Completed 680/5000 structures... Found 621 negative examples so farDownloading PDB structure '6trq'...
#
# Desired structure doesn't exist
# Downloading PDB structure '1h15'...
# Downloading PDB structure '1bve'...
# Downloading PDB structure '6c8x'...
# Downloading PDB structure '7gj6'...
# Downloading PDB structure '6vhh'...
# Downloading PDB structure '5ud9'...
# Downloading PDB structure '1tjg'...
# Downloading PDB structure '7kqe'...
# Downloading PDB structure '9f9l'...
# Completed 690/5000 structures... Found 630 negative examples so farDownloading PDB structure '7ge4'...
#
# Downloading PDB structure '5fec'...
# Desired structure doesn't exist
# Downloading PDB structure '5q2i'...
# Downloading PDB structure '7nda'...
# Downloading PDB structure '6b5n'...
# Downloading PDB structure '8uw2'...
# Downloading PDB structure '7grq'...
# Downloading PDB structure '4chg'...
# Downloading PDB structure '1mtr'...
# Downloading PDB structure '3nkn'...
# Completed 700/5000 structures... Found 639 negative examples so farDownloading PDB structure '3oq2'...
#
# Downloading PDB structure '5dwb'...
# Downloading PDB structure '7rm0'...
# Downloading PDB structure '1bix'...
# Downloading PDB structure '5q61'...
# Downloading PDB structure '5jq6'...
# Downloading PDB structure '6nnf'...
# Downloading PDB structure '7eya'...
# Downloading PDB structure '8xxg'...
# Downloading PDB structure '8kg6'...
# Completed 710/5000 structures... Found 649 negative examples so farDownloading PDB structure '8vbm'...
#
# Desired structure doesn't exist
# Downloading PDB structure '8f60'...
# Desired structure doesn't exist
# Downloading PDB structure '7mq9'...
# Downloading PDB structure '7ggb'...
# Downloading PDB structure '2bvw'...
# Desired structure doesn't exist
# Downloading PDB structure '4ktp'...
# Downloading PDB structure '5od8'...
# Downloading PDB structure '9e7w'...
# Downloading PDB structure '3nfs'...
# Desired structure doesn't exist
# Downloading PDB structure '7rbh'...
# Completed 720/5000 structures... Found 655 negative examples so far
# Downloading PDB structure '5q7s'...
# Downloading PDB structure '1ggy'...
# Downloading PDB structure '6sey'...
# Downloading PDB structure '5th2'...
# Downloading PDB structure '1l3e'...
# Downloading PDB structure '3dsd'...
# Downloading PDB structure '9b44'...
# Downloading PDB structure '3nz8'...
# Downloading PDB structure '2zgu'...
# Downloading PDB structure '7r6x'...
# Completed 730/5000 structures... Found 665 negative examples so far
# Downloading PDB structure '5kgx'...
# Downloading PDB structure '8qya'...
# Downloading PDB structure '7x90'...
# Downloading PDB structure '3uvc'...
# Downloading PDB structure '6mag'...
# Downloading PDB structure '7rm2'...
# Downloading PDB structure '2a6k'...
# Downloading PDB structure '8het'...
# Downloading PDB structure '7gkp'...
# Downloading PDB structure '4gho'...
# Completed 740/5000 structures... Found 675 negative examples so far
# Downloading PDB structure '3rh1'...
# Downloading PDB structure '9bo2'...
# Downloading PDB structure '2hwj'...
# Downloading PDB structure '7kq1'...
# Downloading PDB structure '8b8t'...
# Downloading PDB structure '8trs'...
# Downloading PDB structure '5udc'...
# Downloading PDB structure '1qaj'...
# Downloading PDB structure '9bdd'...
# Downloading PDB structure '8u9w'...
# Completed 750/5000 structures... Found 685 negative examples so far
# Downloading PDB structure '6w4b'...
# Downloading PDB structure '1u0n'...
# Downloading PDB structure '3vzi'...
# Downloading PDB structure '6m13'...
# Downloading PDB structure '6ell'...
# Downloading PDB structure '7gn6'...
# Downloading PDB structure '7mxt'...
# Downloading PDB structure '8vnh'...
# Downloading PDB structure '2vkc'...
# Downloading PDB structure '6o48'...
# Completed 760/5000 structures... Found 694 negative examples so far
# Failed 8VNH: Duplicate residue numbering
# Downloading PDB structure '9cay'...
# Downloading PDB structure '7kez'...
# Downloading PDB structure '8ykn'...
# Downloading PDB structure '4p3w'...
# Downloading PDB structure '9atj'...
# Downloading PDB structure '5cyq'...
# Desired structure doesn't exist
# Downloading PDB structure '8t7i'...
# Downloading PDB structure '7icp'...
# Downloading PDB structure '6o3b'...
# Downloading PDB structure '7gdh'...
# Completed 770/5000 structures... Found 703 negative examples so far
# Downloading PDB structure '4mz7'...
# Downloading PDB structure '6ju0'...
# Downloading PDB structure '6wzl'...
# Downloading PDB structure '4q0w'...
# Downloading PDB structure '1tva'...
# Downloading PDB structure '2fd6'...
# Downloading PDB structure '7n62'...
# Downloading PDB structure '3thm'...
# Downloading PDB structure '2k9c'...
# Downloading PDB structure '7eg1'...
# Completed 780/5000 structures... Found 713 negative examples so farDownloading PDB structure '5tb8'...
#
# Downloading PDB structure '8zhc'...
# Downloading PDB structure '7gbs'...
# Desired structure doesn't exist
# Downloading PDB structure '5f8a'...
# Downloading PDB structure '6fab'...
# Downloading PDB structure '11ba'...
# Downloading PDB structure '7gbv'...
# Failed 6FAB: No protein chains found
# Downloading PDB structure '1sn8'...
# Downloading PDB structure '4eyr'...
# Downloading PDB structure '7gax'...
# Completed 790/5000 structures... Found 721 negative examples so far
# Downloading PDB structure '8u4v'...
# Downloading PDB structure '7l8y'...
# Downloading PDB structure '5gnz'...
# Downloading PDB structure '7ycl'...
# Downloading PDB structure '8jq9'...
# Downloading PDB structure '7t6x'...
# Downloading PDB structure '1awz'...
# Downloading PDB structure '8c9u'...
# Downloading PDB structure '7nev'...
# Failed 7YCL: Duplicate residue numbering
# Downloading PDB structure '2hlf'...
# Completed 800/5000 structures... Found 730 negative examples so far
# Downloading PDB structure '6wgl'...
# Desired structure doesn't exist
# Downloading PDB structure '5umi'...
# Downloading PDB structure '7bal'...
# Downloading PDB structure '2moe'...
# Downloading PDB structure '8dib'...
# Downloading PDB structure '6hm5'...
# Downloading PDB structure '5adp'...
# Downloading PDB structure '1zjm'...
# Downloading PDB structure '1ns4'...
# Downloading PDB structure '4ced'...
# Downloading PDB structure '7w2w'...
# Completed 810/5000 structures... Found 738 negative examples so far
# Failed 6HM5: Duplicate residue numbering
# Downloading PDB structure '5lac'...
# Downloading PDB structure '5q68'...
# Downloading PDB structure '7ged'...
# Downloading PDB structure '8g6i'...
# Downloading PDB structure '9bnu'...
# Downloading PDB structure '9fhq'...
# Downloading PDB structure '7l1p'...
# Downloading PDB structure '9ccj'...
# Desired structure doesn't exist
# Downloading PDB structure '7f71'...
# Completed 820/5000 structures... Found 747 negative examples so far
# Downloading PDB structure '7g71'...
# Downloading PDB structure '1sz2'...
# Downloading PDB structure '7fgr'...
# Downloading PDB structure '6wnl'...
# Downloading PDB structure '3jah'...
# Downloading PDB structure '8pab'...
# Downloading PDB structure '7sf3'...
# Desired structure doesn't exist
# Downloading PDB structure '7gge'...
# Desired structure doesn't exist
# Downloading PDB structure '5ah8'...
# Downloading PDB structure '8b9v'...
# Completed 830/5000 structures... Found 755 negative examples so farDownloading PDB structure '8f7m'...
#
# Downloading PDB structure '6mb3'...
# Downloading PDB structure '8fl4'...
# Downloading PDB structure '7l13'...
# Downloading PDB structure '6t56'...
# Desired structure doesn't exist
# Downloading PDB structure '8sir'...
# Downloading PDB structure '5w2b'...
# Downloading PDB structure '2oxw'...
# Downloading PDB structure '4mo3'...
# Downloading PDB structure '6zto'...
# Completed 840/5000 structures... Found 764 negative examples so farDownloading PDB structure '4cc8'...
#
# Downloading PDB structure '7swx'...
# Downloading PDB structure '9iy0'...
# Desired structure doesn't exist
# Downloading PDB structure '5i66'...
# Downloading PDB structure '6arz'...
# Downloading PDB structure '7ewj'...
# Downloading PDB structure '4tny'...
# Downloading PDB structure '5sx5'...
# Downloading PDB structure '5a04'...
# Downloading PDB structure '7myx'...
# Completed 850/5000 structures... Found 773 negative examples so far
# Downloading PDB structure '1ae6'...
# Downloading PDB structure '5lzz'...
# Downloading PDB structure '8e6b'...
# Downloading PDB structure '7u2u'...
# Downloading PDB structure '2fxd'...
# Downloading PDB structure '7ghp'...
# Desired structure doesn't exist
# Downloading PDB structure '1iqd'...
# Downloading PDB structure '6t3m'...
# Downloading PDB structure '7mho'...
# Downloading PDB structure '1h53'...
# Completed 860/5000 structures... Found 782 negative examples so far
# Downloading PDB structure '6vrk'...
# Downloading PDB structure '6idk'...
# Downloading PDB structure '3vf7'...
# Downloading PDB structure '9b0f'...
# Downloading PDB structure '8a5b'...
# Downloading PDB structure '4mzp'...
# Desired structure doesn't exist
# Downloading PDB structure '1hpv'...
# Downloading PDB structure '7y7h'...
# Downloading PDB structure '3huf'...
# Downloading PDB structure '7x8w'...
# Desired structure doesn't exist
# Completed 870/5000 structures... Found 790 negative examples so far
# Downloading PDB structure '8t1r'...
# Downloading PDB structure '3ajv'...
# Downloading PDB structure '7gem'...
# Failed 7X8W: Duplicate residue numberingDownloading PDB structure '6orn'...
#
# Downloading PDB structure '3uc0'...
# Downloading PDB structure '8yby'...
# Downloading PDB structure '7g52'...
# Downloading PDB structure '7pnp'...
# Downloading PDB structure '3spl'...
# Downloading PDB structure '7k3b'...
# Completed 880/5000 structures... Found 799 negative examples so far
# Downloading PDB structure '6pbv'...
# Downloading PDB structure '3f17'...
# Downloading PDB structure '1s48'...
# Downloading PDB structure '5rfa'...
# Downloading PDB structure '4kld'...
# Downloading PDB structure '7xny'...
# Downloading PDB structure '4ep5'...
# Downloading PDB structure '7gci'...
# Downloading PDB structure '7qi6'...
# Downloading PDB structure '3wfh'...
# Completed 890/5000 structures... Found 809 negative examples so far
# Downloading PDB structure '6zm6'...
# Desired structure doesn't exist
# Downloading PDB structure '6wlc'...
# Downloading PDB structure '2a8s'...
# Desired structure doesn't exist
# Downloading PDB structure '3slz'...
# Downloading PDB structure '1uj3'...
# Desired structure doesn't exist
# Downloading PDB structure '8d48'...
# Downloading PDB structure '7glx'...
# Downloading PDB structure '3qrr'...
# Failed 1UJ3: Duplicate residue numbering
# Downloading PDB structure '8v4f'...
# Downloading PDB structure '6erp'...
# Completed 900/5000 structures... Found 815 negative examples so far
# Downloading PDB structure '4lly'...
# Downloading PDB structure '8smk'...
# Downloading PDB structure '2a8r'...
# Downloading PDB structure '8hvy'...
# Downloading PDB structure '7zlw'...
# Downloading PDB structure '1fib'...
# Downloading PDB structure '3ds5'...
# Downloading PDB structure '5fkv'...
# Downloading PDB structure '5yad'...
# Downloading PDB structure '6xcm'...
# Completed 910/5000 structures... Found 825 negative examples so farDownloading PDB structure '7g5c'...
#
# Downloading PDB structure '9inm'...
# Downloading PDB structure '1h52'...
# Downloading PDB structure '4ogy'...
# Downloading PDB structure '5wea'...
# Downloading PDB structure '7bg1'...
# Downloading PDB structure '3p56'...
# Downloading PDB structure '3avi'...
# Downloading PDB structure '5sag'...
# Downloading PDB structure '4mk1'...
# Downloading PDB structure '7q0a'...Completed 920/5000 structures... Found 835 negative examples so far
#
# Downloading PDB structure '7t01'...
# Downloading PDB structure '7l7r'...
# Downloading PDB structure '4ao1'...
# Downloading PDB structure '9avq'...
# Downloading PDB structure '7mhn'...
# Downloading PDB structure '7of4'...
# Downloading PDB structure '7odr'...
# Downloading PDB structure '2cmr'...
# Desired structure doesn't exist
# Downloading PDB structure '4ug0'...
# Desired structure doesn't exist
# Downloading PDB structure '8tq1'...
# Completed 930/5000 structures... Found 843 negative examples so far
# Downloading PDB structure '7uyn'...
# Desired structure doesn't exist
# Downloading PDB structure '9ata'...
# Downloading PDB structure '7gia'...
# Downloading PDB structure '3e38'...
# Desired structure doesn't exist
# Downloading PDB structure '1b6j'...
# Downloading PDB structure '5ywu'...
# Downloading PDB structure '7g2y'...
# Downloading PDB structure '7wkx'...
# Downloading PDB structure '6ea6'...
# Completed 940/5000 structures... Found 851 negative examples so farDownloading PDB structure '4ub1'...
#
# Failed 7WKX: Duplicate residue numbering
# Downloading PDB structure '7tax'...
# Downloading PDB structure '7w33'...
# Downloading PDB structure '6jhz'...
# Downloading PDB structure '8udp'...
# Downloading PDB structure '7t28'...
# Downloading PDB structure '6wb0'...
# Downloading PDB structure '4hi3'...
# Downloading PDB structure '7pry'...
# Downloading PDB structure '3b6o'...
# Completed 950/5000 structures... Found 860 negative examples so farDownloading PDB structure '1yvs'...
#
# Failed 7PRY: No protein chains foundDownloading PDB structure '5q2y'...
#
# Downloading PDB structure '6dbx'...
# Downloading PDB structure '6wkl'...
# Downloading PDB structure '6ogx'...
# Downloading PDB structure '2qd8'...
# Downloading PDB structure '7glv'...
# Downloading PDB structure '9rj5'...
# Downloading PDB structure '1fbr'...
# Downloading PDB structure '5tpw'...
# Completed 960/5000 structures... Found 869 negative examples so farDownloading PDB structure '7upk'...
#
# Downloading PDB structure '1woq'...
# Desired structure doesn't exist
# Downloading PDB structure '1dqb'...
# Downloading PDB structure '2x6s'...
# Downloading PDB structure '7g2j'...
# Downloading PDB structure '7ukm'...
# Downloading PDB structure '7u04'...
# Downloading PDB structure '1ru9'...
# Downloading PDB structure '1yqv'...
# Downloading PDB structure '9rm2'...
# Completed 970/5000 structures... Found 878 negative examples so far
# Downloading PDB structure '4nm2'...
# Downloading PDB structure '6zok'...
# Downloading PDB structure '8r60'...
# Downloading PDB structure '7m00'...
# Downloading PDB structure '6x9x'...
# Failed 6ZOK: No protein chains foundDownloading PDB structure '3p11'...
#
# Downloading PDB structure '3hpl'...
# Downloading PDB structure '1pkq'...
# Downloading PDB structure '8dkd'...
# Downloading PDB structure '8ds0'...
# Completed 980/5000 structures... Found 887 negative examples so far
# Downloading PDB structure '4xbg'...
# Failed 3HPL: Duplicate residue numbering
# Downloading PDB structure '6mz0'...
# Downloading PDB structure '8gfr'...
# Downloading PDB structure '7e3c'...
# Downloading PDB structure '6grd'...
# Downloading PDB structure '4c8y'...
# Downloading PDB structure '6t3f'...
# Downloading PDB structure '1qyg'...
# Downloading PDB structure '1gmp'...
# Downloading PDB structure '9ibx'...
# Completed 990/5000 structures... Found 896 negative examples so far
# Downloading PDB structure '2diu'...
# Downloading PDB structure '6o29'...
# Downloading PDB structure '7ycn'...
# Downloading PDB structure '8rc2'...
# Downloading PDB structure '1tet'...
# Downloading PDB structure '4pex'...
# Downloading PDB structure '7u5e'...
# Downloading PDB structure '5lgh'...
# Downloading PDB structure '2l1c'...
# Downloading PDB structure '9g8p'...
# Completed 1000/5000 structures... Found 906 negative examples so far
# Downloading PDB structure '9b7v'...
# Downloading PDB structure '6okm'...
# Desired structure doesn't exist
# Downloading PDB structure '8zyc'...
# Downloading PDB structure '8icn'...
# Downloading PDB structure '9bbq'...
# Desired structure doesn't exist
# Downloading PDB structure '6vqy'...
# Downloading PDB structure '7g2m'...
# Downloading PDB structure '6pjm'...
# Downloading PDB structure '5a74'...
# Downloading PDB structure '2aoj'...
# Completed 1010/5000 structures... Found 914 negative examples so far
# Downloading PDB structure '6ncp'...
# Downloading PDB structure '5hyq'...
# Downloading PDB structure '7knw'...
# Downloading PDB structure '7n47'...
# Downloading PDB structure '5cil'...
# Downloading PDB structure '8bga'...
# Downloading PDB structure '7ly3'...
# Downloading PDB structure '7z2m'...
# Downloading PDB structure '8g40'...
# Completed 1020/5000 structures... Found 924 negative examples so far
# Downloading PDB structure '4cie'...
# Downloading PDB structure '8aiv'...
# Downloading PDB structure '7skr'...
# Downloading PDB structure '5q5c'...
# Desired structure doesn't exist
# Downloading PDB structure '7kpg'...
# Downloading PDB structure '4lh4'...
# Downloading PDB structure '8zrz'...
# Downloading PDB structure '7xmx'...
# Downloading PDB structure '8wts'...
# Downloading PDB structure '2gz8'...
# Downloading PDB structure '4u1i'...
# ...
# Downloading PDB structure '3i67'...
# Downloading PDB structure '7gdx'...Completed 4670/5000 structures... Found 4253 negative examples so far
#
# Downloading PDB structure '6yqv'...
# Downloading PDB structure '7ufy'...
# Downloading PDB structure '4a2o'...
# Downloading PDB structure '6dcq'...
# Downloading PDB structure '6xqu'...
# Downloading PDB structure '7m8o'...
# Downloading PDB structure '4mm3'...
# Downloading PDB structure '8veg'...
# Downloading PDB structure '4xcc'...
# Completed 4680/5000 structures... Found 4263 negative examples so far
# Downloading PDB structure '5fv7'...
# Downloading PDB structure '6lwj'...
# Downloading PDB structure '1msm'...
# Downloading PDB structure '8jn2'...
# Downloading PDB structure '3ekx'...
# Downloading PDB structure '4wyv'...
# Downloading PDB structure '5wux'...
# Downloading PDB structure '5ytv'...
# Downloading PDB structure '7s74'...
# Downloading PDB structure '3b2v'...
# Completed 4690/5000 structures... Found 4273 negative examples so far
# Downloading PDB structure '4xxd'...
# Downloading PDB structure '8uls'...
# Downloading PDB structure '1jpt'...
# Downloading PDB structure '2r5q'...
# Downloading PDB structure '7ghr'...
# Desired structure doesn't exist
# Downloading PDB structure '3gbn'...
# Downloading PDB structure '8xgc'...
# Downloading PDB structure '7pcr'...
# Downloading PDB structure '4wmd'...
# Downloading PDB structure '5whj'...
# Desired structure doesn't exist
# Completed 4700/5000 structures... Found 4281 negative examples so far
# Downloading PDB structure '6cil'...
# Downloading PDB structure '1lk3'...
# Downloading PDB structure '7prj'...
# Downloading PDB structure '9mif'...
# Downloading PDB structure '3q4j'...
# Downloading PDB structure '5nw9'...
# Downloading PDB structure '6wet'...
# Downloading PDB structure '8qov'...
# Desired structure doesn't exist
# Downloading PDB structure '7uqc'...
# Downloading PDB structure '7tll'...
# Downloading PDB structure '4f1h'...Completed 4710/5000 structures... Found 4290 negative examples so far
#
# Downloading PDB structure '5kao'...
# Downloading PDB structure '6ctt'...
# Downloading PDB structure '6oxw'...
# Downloading PDB structure '6ole'...
# Downloading PDB structure '2pfy'...
# Downloading PDB structure '8icr'...
# Downloading PDB structure '3o4n'...
# Desired structure doesn't exist
# Downloading PDB structure '7gjc'...
# Downloading PDB structure '3k9j'...
# Downloading PDB structure '5q9y'...Completed 4720/5000 structures... Found 4299 negative examples so far
#
# Downloading PDB structure '7t25'...
# Downloading PDB structure '5q8u'...
# Downloading PDB structure '8ceu'...
# Downloading PDB structure '9dmf'...
# Downloading PDB structure '1zj7'...
# Downloading PDB structure '7ger'...
# Downloading PDB structure '5qom'...
# Downloading PDB structure '7to5'...
# Downloading PDB structure '3way'...
# Completed 4730/5000 structures... Found 4309 negative examples so far
# Downloading PDB structure '7gnr'...
# Downloading PDB structure '4jpi'...
# Downloading PDB structure '1b96'...
# Downloading PDB structure '6dj7'...
# Downloading PDB structure '8fwh'...
# Downloading PDB structure '2hpm'...
# Downloading PDB structure '5wkk'...
# Downloading PDB structure '6e3r'...
# Desired structure doesn't exist
# Downloading PDB structure '8hut'...
# Downloading PDB structure '9ats'...
# Downloading PDB structure '5fb8'...
# Completed 4740/5000 structures... Found 4318 negative examples so far
# Downloading PDB structure '3di7'...
# Desired structure doesn't exist
# Downloading PDB structure '8j7e'...
# Downloading PDB structure '5uhy'...
# Downloading PDB structure '8ehj'...
# Downloading PDB structure '1sdt'...
# Downloading PDB structure '6tur'...
# Downloading PDB structure '5q35'...
# Desired structure doesn't exist
# Downloading PDB structure '3wax'...
# Downloading PDB structure '5b0j'...
# Completed 4750/5000 structures... Found 4326 negative examples so far
# Downloading PDB structure '3at0'...
# Downloading PDB structure '3i8o'...
# Downloading PDB structure '4aqx'...
# Downloading PDB structure '3dph'...
# Downloading PDB structure '6ysj'...
# Downloading PDB structure '8ehm'...
# Downloading PDB structure '6dw7'...
# Downloading PDB structure '1baf'...
# Downloading PDB structure '8zaw'...
# Downloading PDB structure '2f8g'...
# Completed 4760/5000 structures... Found 4336 negative examples so far
# Downloading PDB structure '3i6j'...
# Downloading PDB structure '8zhe'...
# Downloading PDB structure '9c6c'...
# Downloading PDB structure '7geh'...
# Downloading PDB structure '5cgy'...
# Downloading PDB structure '6ieq'...
# Downloading PDB structure '4m5z'...
# Downloading PDB structure '3isw'...
# Downloading PDB structure '7ral'...
# Downloading PDB structure '9cjr'...
# Completed 4770/5000 structures... Found 4346 negative examples so far
# Downloading PDB structure '9axn'...
# Failed 6IEQ: Duplicate residue numbering
# Downloading PDB structure '5t78'...
# Downloading PDB structure '8w85'...
# Downloading PDB structure '8tvd'...
# Downloading PDB structure '5co7'...
# Downloading PDB structure '3f7y'...
# Downloading PDB structure '7g4h'...
# Downloading PDB structure '3h8c'...
# Downloading PDB structure '6hak'...
# Downloading PDB structure '4fxi'...
# Completed 4780/5000 structures... Found 4355 negative examples so far
# Downloading PDB structure '9mpc'...
# Downloading PDB structure '7g4y'...
# Downloading PDB structure '2zgo'...
# Downloading PDB structure '4yc2'...
# Downloading PDB structure '7m02'...
# Downloading PDB structure '7dgg'...
# Downloading PDB structure '6x7v'...
# Downloading PDB structure '6t9d'...
# Downloading PDB structure '8rex'...
# Downloading PDB structure '1eri'...
# Desired structure doesn't exist
# Completed 4790/5000 structures... Found 4364 negative examples so far
# Downloading PDB structure '6rrg'...
# Downloading PDB structure '1yqm'...
# Downloading PDB structure '8bbh'...
# Downloading PDB structure '6x1b'...
# Desired structure doesn't exist
# Downloading PDB structure '6b1q'...
# Downloading PDB structure '7i1f'...
# Downloading PDB structure '3m3c'...
# Downloading PDB structure '4dqh'...
# Downloading PDB structure '9el4'...
# Downloading PDB structure '8e8y'...
# Downloading PDB structure '8gng'...
# Completed 4800/5000 structures... Found 4373 negative examples so far
# Downloading PDB structure '9dao'...
# Downloading PDB structure '7g7t'...
# Downloading PDB structure '3vgm'...
# Downloading PDB structure '4iuj'...
# Downloading PDB structure '4gcw'...
# Downloading PDB structure '5bo1'...
# Downloading PDB structure '1ucn'...
# Downloading PDB structure '7si9'...
# Downloading PDB structure '5q7r'...
# Completed 4810/5000 structures... Found 4383 negative examples so farDownloading PDB structure '5zam'...
#
# Downloading PDB structure '8dmh'...
# Downloading PDB structure '3h36'...
# Downloading PDB structure '8j3a'...
# Downloading PDB structure '6x9s'...
# Downloading PDB structure '1deq'...
# Downloading PDB structure '1jgl'...
# Downloading PDB structure '6mh2'...
# Downloading PDB structure '4ea4'...
# Downloading PDB structure '8ifp'...
# Downloading PDB structure '7nd7'...
# Completed 4820/5000 structures... Found 4393 negative examples so far
# Downloading PDB structure '7q4q'...
# Downloading PDB structure '7x29'...
# Downloading PDB structure '7e6p'...
# Downloading PDB structure '4g9d'...
# Downloading PDB structure '1c6v'...
# Downloading PDB structure '6vyj'...
# Downloading PDB structure '6gxv'...
# Downloading PDB structure '5do8'...
# Downloading PDB structure '2ykl'...
# Completed 4830/5000 structures... Found 4403 negative examples so farDownloading PDB structure '5mhg'...
#
# Downloading PDB structure '8q3z'...
# Downloading PDB structure '6kns'...
# Downloading PDB structure '4gw6'...
# Downloading PDB structure '2fms'...
# Downloading PDB structure '7my5'...
# Failed 6KNS: No protein chains found
# Downloading PDB structure '5u6s'...
# Downloading PDB structure '7g2i'...
# Downloading PDB structure '3fhg'...
# Downloading PDB structure '7gcu'...
# Completed 4840/5000 structures... Found 4412 negative examples so farDownloading PDB structure '4ekk'...
#
# Downloading PDB structure '4g8i'...
# Downloading PDB structure '7grs'...
# Downloading PDB structure '6xe1'...
# Downloading PDB structure '6vqd'...
# Downloading PDB structure '4k2u'...
# Downloading PDB structure '3qo1'...
# Downloading PDB structure '1cft'...
# Downloading PDB structure '1hni'...
# Downloading PDB structure '5d65'...
# Downloading PDB structure '5vrx'...Completed 4850/5000 structures... Found 4422 negative examples so far
#
# Downloading PDB structure '7gbz'...
# Downloading PDB structure '7g4z'...
# Downloading PDB structure '8cae'...
# Downloading PDB structure '3c4t'...
# Downloading PDB structure '6dgx'...
# Downloading PDB structure '6x1v'...
# Downloading PDB structure '7lks'...
# Downloading PDB structure '9ick'...
# Downloading PDB structure '5w5z'...
# Downloading PDB structure '5qhm'...Completed 4860/5000 structures... Found 4432 negative examples so far
#
# Downloading PDB structure '7ki6'...
# Downloading PDB structure '6oeq'...
# Failed 5W5Z: Duplicate residue numbering
# Downloading PDB structure '6ss2'...
# Downloading PDB structure '4gtz'...
# Desired structure doesn't exist
# Downloading PDB structure '5ywv'...
# Downloading PDB structure '4hs6'...
# Downloading PDB structure '1dut'...
# Downloading PDB structure '3bc3'...
# Downloading PDB structure '7g3z'...
# Completed 4870/5000 structures... Found 4440 negative examples so far
# Downloading PDB structure '7k0h'...
# Downloading PDB structure '8rel'...
# Downloading PDB structure '3ey1'...
# Downloading PDB structure '7m9l'...
# Downloading PDB structure '7e9b'...
# Downloading PDB structure '9ggb'...
# Downloading PDB structure '3ots'...
# Downloading PDB structure '1f7a'...
# Downloading PDB structure '6cpn'...
# Desired structure doesn't exist
# Downloading PDB structure '9l6z'...
# Completed 4880/5000 structures... Found 4449 negative examples so far
# Downloading PDB structure '6vyy'...
# Downloading PDB structure '1ncd'...
# Downloading PDB structure '3q8l'...
# Downloading PDB structure '7g44'...
# Desired structure doesn't exist
# Downloading PDB structure '8ue0'...
# Downloading PDB structure '8th1'...
# Downloading PDB structure '3vgl'...
# Downloading PDB structure '7toq'...
# Downloading PDB structure '3ec0'...
# Downloading PDB structure '7x6k'...Completed 4890/5000 structures... Found 4457 negative examples so far
# Failed 8TH1: Duplicate residue numbering
# Downloading PDB structure '7d3c'...
#
# Desired structure doesn't exist
# Downloading PDB structure '2axl'...
# Downloading PDB structure '3lzu'...
# Downloading PDB structure '4h7w'...
# Downloading PDB structure '4w8t'...
# Downloading PDB structure '8uih'...
# Downloading PDB structure '6iut'...
# Downloading PDB structure '7vk5'...
# Downloading PDB structure '8k22'...
# Downloading PDB structure '4py8'...
# Completed 4900/5000 structures... Found 4466 negative examples so farDownloading PDB structure '5etu'...
#
# Desired structure doesn't exist
# Downloading PDB structure '9b0h'...
# Downloading PDB structure '7gk1'...
# Downloading PDB structure '5ijq'...
# Desired structure doesn't exist
# Downloading PDB structure '8c8j'...
# Downloading PDB structure '5my4'...
# Downloading PDB structure '7s73'...
# Downloading PDB structure '7li8'...
# Downloading PDB structure '6bb4'...
# Downloading PDB structure '3jw2'...
# Completed 4910/5000 structures... Found 4474 negative examples so far
# Downloading PDB structure '4fcy'...
# Downloading PDB structure '6w5d'...
# Downloading PDB structure '7g4j'...
# Downloading PDB structure '4ndf'...
# Downloading PDB structure '3iga'...
# Downloading PDB structure '3nkr'...
# Failed 7G4J: Duplicate residue numbering
# Downloading PDB structure '7gg1'...
# Downloading PDB structure '5zkj'...
# Downloading PDB structure '6ke1'...
# Downloading PDB structure '7gi8'...
# Failed 3IGA: No protein chains found
# Completed 4920/5000 structures... Found 4482 negative examples so far
# Downloading PDB structure '1e21'...
# Downloading PDB structure '8us8'...
# Downloading PDB structure '9bsg'...
# Downloading PDB structure '6mn7'...
# Downloading PDB structure '4qn0'...
# Downloading PDB structure '6mv5'...
# Desired structure doesn't exist
# Downloading PDB structure '5ft1'...
# Downloading PDB structure '9b7w'...
# Downloading PDB structure '1a7o'...
# Downloading PDB structure '7ndd'...
# Desired structure doesn't exist
# Completed 4930/5000 structures... Found 4491 negative examples so far
# Downloading PDB structure '8ez3'...
# Downloading PDB structure '4v6m'...
# Downloading PDB structure '4b36'...
# Desired structure doesn't exist
# Downloading PDB structure '1clo'...
# Downloading PDB structure '3ifo'...
# Downloading PDB structure '7gfh'...
# Downloading PDB structure '6bi2'...
# Downloading PDB structure '3phq'...
# Downloading PDB structure '5vrj'...
# Downloading PDB structure '6t6i'...
# Downloading PDB structure '8dz5'...Completed 4940/5000 structures... Found 4499 negative examples so far
#
# Downloading PDB structure '4ojr'...
# Downloading PDB structure '9rht'...
# Downloading PDB structure '9cr9'...
# Downloading PDB structure '4dj4'...
# Downloading PDB structure '8inu'...
# Desired structure doesn't exist
# Downloading PDB structure '7ghi'...
# Downloading PDB structure '8ivx'...
# Downloading PDB structure '7vk8'...
# Downloading PDB structure '6lnb'...
# Desired structure doesn't exist
# Completed 4950/5000 structures... Found 4507 negative examples so far
# Downloading PDB structure '8t4s'...
# Downloading PDB structure '8c77'...
# Downloading PDB structure '5oca'...
# Downloading PDB structure '6v6w'...
# Downloading PDB structure '8sve'...
# Downloading PDB structure '4zoc'...
# Downloading PDB structure '2azc'...
# Downloading PDB structure '4to6'...
# Downloading PDB structure '5saf'...
# Failed 6V6W: Duplicate residue numbering
# Downloading PDB structure '1b8h'...
# Completed 4960/5000 structures... Found 4516 negative examples so far
# Downloading PDB structure '2bpz'...
# Downloading PDB structure '3f1v'...
# Downloading PDB structure '7w2s'...
# Downloading PDB structure '3pvi'...
# Downloading PDB structure '5i43'...
# Downloading PDB structure '6e3w'...
# Downloading PDB structure '3n3w'...
# Downloading PDB structure '6d0d'...
# Downloading PDB structure '1yeg'...
# Downloading PDB structure '7gn7'...
# Completed 4970/5000 structures... Found 4526 negative examples so farDownloading PDB structure '8sxp'...
#
# Downloading PDB structure '7s9n'...
# Downloading PDB structure '6k1c'...
# Downloading PDB structure '7x63'...
# Downloading PDB structure '9nb9'...
# Downloading PDB structure '5mp0'...
# Downloading PDB structure '2na2'...
# Downloading PDB structure '5tba'...
# Downloading PDB structure '5dlt'...
# Downloading PDB structure '4rxm'...
# Completed 4980/5000 structures... Found 4536 negative examples so farDownloading PDB structure '3wfc'...
#
# Downloading PDB structure '4qhn'...
# Downloading PDB structure '3i2c'...
# Downloading PDB structure '3tfr'...
# Downloading PDB structure '4nm1'...
# Failed 3I2C: Duplicate residue numbering
# Downloading PDB structure '5wct'...
# Downloading PDB structure '8gxi'...
# Downloading PDB structure '5gnx'...
# Downloading PDB structure '1r11'...
# Downloading PDB structure '1mhp'...
# Completed 4990/5000 structures... Found 4545 negative examples so far
# Downloading PDB structure '1p7k'...
# Downloading PDB structure '8hvk'...
# Downloading PDB structure '7zjx'...
# Desired structure doesn't exist
# Downloading PDB structure '6fb9'...
# Downloading PDB structure '7upd'...
# Failed 1P7K: Duplicate residue numbering
# Downloading PDB structure '2c06'...
# Downloading PDB structure '3wlj'...
# Completed 5000/5000 structures... Found 4553 negative examples so far
#
# Completed! Found 4553 negative examples
# Successfully processed: 4890/5000 structures
# Failed: 110 structures
# Exporting 4553 negative examples...
# INFO:__main__:Merging with positive dataset...
# INFO:__main__:Loading positive dataset...
# ✓ Exported to negative_examples_temp.csv
# INFO:__main__:Loaded 35698 positive examples
# INFO:__main__:Merge complete!
# INFO:__main__:Final dataset: 40251 total examples
# INFO:__main__:  - Positive (binding): 35698
# INFO:__main__:  - Negative (non-binding): 4553
# INFO:__main__:  - Balance ratio: 0.13
# ============================================================
# SUCCESS! Merged dataset saved to: merged_protein_dataset.csv
# Processed 4553 negative examples
# Failed: 110 structures
# ============================================================
